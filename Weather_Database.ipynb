# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
#weather_api_key = ""
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | broken hill
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | ilam
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | tura
# Processing Record 9 of Set 1 | ust-ishim
# Processing Record 10 of Set 1 | ancud
# Processing Record 11 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | faya
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | itacoatiara
# Processing Record 21 of Set 1 | magdagachi
# Processing Record 22 of Set 1 | quatre cocos
# Processing Record 23 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | sinnamary
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | plettenberg bay
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | la sarre
# Processing Record 49 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 1 | krylovskaya
# Processing Record 1 of Set 2 | taltal
# Processing Record 2 of Set 2 | sao jose da coroa grande
# Processing Record 3 of Set 2 | berdigestyakh
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | nemuro
# Processing Record 6 of Set 2 | abu samrah
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | chernyshevskiy
# Processing Record 11 of Set 2 | waterfoot
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | san patricio
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | kattivakkam
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | jawar
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | naryan-mar
# Processing Record 21 of Set 2 | novooleksiyivka
# Processing Record 22 of Set 2 | pandan
# Processing Record 23 of Set 2 | bud
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | westport
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | mukhanovo
# City not found. Skipping...
# Processing Record 28 of Set 2 | galveston
# Processing Record 29 of Set 2 | khani
# Processing Record 30 of Set 2 | aswan
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | awbari
# Processing Record 33 of Set 2 | grafton
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | great bend
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 2 | angoche
# Processing Record 40 of Set 2 | chakradharpur
# Processing Record 41 of Set 2 | port hedland
# Processing Record 42 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | moerai
# Processing Record 46 of Set 2 | vilhena
# Processing Record 47 of Set 2 | jiwani
# Processing Record 48 of Set 2 | lichinga
# Processing Record 49 of Set 2 | alassio
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | vila velha
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | liverpool
# Processing Record 5 of Set 3 | buala
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | matagami
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | high prairie
# Processing Record 10 of Set 3 | saint-pierre
# Processing Record 11 of Set 3 | yarmouth
# Processing Record 12 of Set 3 | rockland
# Processing Record 13 of Set 3 | shingu
# Processing Record 14 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | santa maria
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 21 of Set 3 | ascension
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | bernay
# Processing Record 24 of Set 3 | itarema
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | vysokovsk
# Processing Record 27 of Set 3 | bonavista
# Processing Record 28 of Set 3 | kudahuvadhoo
# Processing Record 29 of Set 3 | peremyshl
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | graaff-reinet
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | kjopsvik
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | tymovskoye
# Processing Record 38 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | sorong
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | umm kaddadah
# Processing Record 43 of Set 3 | pacifica
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | brownwood
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | constitucion
# Processing Record 49 of Set 3 | san pedro
# Processing Record 50 of Set 3 | bodmin
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | khandyga
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | douglas
# Processing Record 6 of Set 4 | derzhavinsk
# Processing Record 7 of Set 4 | biryukove
# Processing Record 8 of Set 4 | paso de carrasco
# Processing Record 9 of Set 4 | botlikh
# Processing Record 10 of Set 4 | warrington
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | san andres
# Processing Record 13 of Set 4 | metro
# Processing Record 14 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 4 | cacu
# Processing Record 16 of Set 4 | troitsko-pechorsk
# Processing Record 17 of Set 4 | poum
# Processing Record 18 of Set 4 | santa rosa de osos
# Processing Record 19 of Set 4 | oussouye
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | lanxi
# Processing Record 22 of Set 4 | placido de castro
# Processing Record 23 of Set 4 | guymon
# Processing Record 24 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | tchibanga
# Processing Record 29 of Set 4 | chkalovskoye
# Processing Record 30 of Set 4 | severo-yeniseyskiy
# Processing Record 31 of Set 4 | mogadishu
# Processing Record 32 of Set 4 | dombarovskiy
# Processing Record 33 of Set 4 | siniscola
# Processing Record 34 of Set 4 | sept-iles
# Processing Record 35 of Set 4 | avarua
# Processing Record 36 of Set 4 | inta
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | florianopolis
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | sistranda
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | pavino
# Processing Record 44 of Set 4 | yellowknife
# Processing Record 45 of Set 4 | busselton
# Processing Record 46 of Set 4 | telma
# Processing Record 47 of Set 4 | gillette
# Processing Record 48 of Set 4 | gat
# Processing Record 49 of Set 4 | irbeyskoye
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | fairbanks
# Processing Record 4 of Set 5 | imisli
# City not found. Skipping...
# Processing Record 5 of Set 5 | basoko
# Processing Record 6 of Set 5 | kenai
# Processing Record 7 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 5 | sterling
# Processing Record 10 of Set 5 | russkaya polyana
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | husavik
# Processing Record 14 of Set 5 | podporozhye
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | faanui
# Processing Record 17 of Set 5 | qaqortoq
# Processing Record 18 of Set 5 | port macquarie
# Processing Record 19 of Set 5 | la palma
# Processing Record 20 of Set 5 | black river
# Processing Record 21 of Set 5 | wajima
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | milkovo
# Processing Record 24 of Set 5 | kigoma
# Processing Record 25 of Set 5 | yaan
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | cockburn town
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 5 | chapais
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | gull lake
# Processing Record 34 of Set 5 | constanta
# Processing Record 35 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 5 | dubuque
# Processing Record 37 of Set 5 | portland
# Processing Record 38 of Set 5 | evanston
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | jacareacanga
# Processing Record 41 of Set 5 | saint-denis
# Processing Record 42 of Set 5 | pedasi
# Processing Record 43 of Set 5 | namatanai
# Processing Record 44 of Set 5 | hovd
# Processing Record 45 of Set 5 | mareeba
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | kastamonu
# Processing Record 49 of Set 5 | khasan
# Processing Record 50 of Set 5 | hanmer springs
# Processing Record 1 of Set 6 | owando
# Processing Record 2 of Set 6 | miyazu
# Processing Record 3 of Set 6 | yulara
# Processing Record 4 of Set 6 | funadhoo
# Processing Record 5 of Set 6 | maceio
# Processing Record 6 of Set 6 | athabasca
# Processing Record 7 of Set 6 | sidi ali
# Processing Record 8 of Set 6 | ust-karsk
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | umm lajj
# Processing Record 11 of Set 6 | cherskiy
# Processing Record 12 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | eureka
# Processing Record 15 of Set 6 | grand gaube
# Processing Record 16 of Set 6 | kananga
# Processing Record 17 of Set 6 | luica
# Processing Record 18 of Set 6 | milos
# Processing Record 19 of Set 6 | businga
# Processing Record 20 of Set 6 | palana
# Processing Record 21 of Set 6 | boa vista
# Processing Record 22 of Set 6 | nipawin
# Processing Record 23 of Set 6 | talara
# Processing Record 24 of Set 6 | shipitsyno
# Processing Record 25 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 26 of Set 6 | joao pinheiro
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | yar-sale
# Processing Record 29 of Set 6 | baruun-urt
# Processing Record 30 of Set 6 | namtsy
# Processing Record 31 of Set 6 | khokholskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | nantucket
# Processing Record 34 of Set 6 | tulun
# Processing Record 35 of Set 6 | kerchevskiy
# Processing Record 36 of Set 6 | ucluelet
# Processing Record 37 of Set 6 | hami
# Processing Record 38 of Set 6 | nago
# Processing Record 39 of Set 6 | bayir
# Processing Record 40 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 6 | charlestown
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | sangar
# Processing Record 47 of Set 6 | acarau
# Processing Record 48 of Set 6 | oranjestad
# Processing Record 49 of Set 6 | nobeoka
# Processing Record 50 of Set 6 | namie
# Processing Record 1 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | lethem
# Processing Record 4 of Set 7 | nadym
# Processing Record 5 of Set 7 | mantua
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | tuatapere
# Processing Record 8 of Set 7 | haapiti
# Processing Record 9 of Set 7 | tazovskiy
# Processing Record 10 of Set 7 | isiro
# Processing Record 11 of Set 7 | yakeshi
# Processing Record 12 of Set 7 | nador
# Processing Record 13 of Set 7 | butembo
# Processing Record 14 of Set 7 | ejura
# Processing Record 15 of Set 7 | balkanabat
# Processing Record 16 of Set 7 | iturama
# Processing Record 17 of Set 7 | whitianga
# Processing Record 18 of Set 7 | perth
# Processing Record 19 of Set 7 | beloha
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | santa rosalia
# Processing Record 22 of Set 7 | krasnyy chikoy
# Processing Record 23 of Set 7 | ewa beach
# Processing Record 24 of Set 7 | adrar
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | innisfail
# Processing Record 27 of Set 7 | saharanpur
# Processing Record 28 of Set 7 | ust-kuyga
# Processing Record 29 of Set 7 | akcaabat
# Processing Record 30 of Set 7 | ono
# Processing Record 31 of Set 7 | theunissen
# Processing Record 32 of Set 7 | terrace
# Processing Record 33 of Set 7 | coihaique
# Processing Record 34 of Set 7 | kushiro
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | kalmunai
# Processing Record 37 of Set 7 | xichang
# Processing Record 38 of Set 7 | mahebourg
# Processing Record 39 of Set 7 | kirakira
# Processing Record 40 of Set 7 | canmore
# Processing Record 41 of Set 7 | waiuku
# Processing Record 42 of Set 7 | verkhnyaya inta
# Processing Record 43 of Set 7 | ribeira grande
# Processing Record 44 of Set 7 | baiyin
# Processing Record 45 of Set 7 | sines
# Processing Record 46 of Set 7 | raahe
# Processing Record 47 of Set 7 | majene
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | verkhnevilyuysk
# Processing Record 50 of Set 7 | bratsk
# Processing Record 1 of Set 8 | sao felix do xingu
# Processing Record 2 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 8 | gouyave
# Processing Record 4 of Set 8 | riverton
# Processing Record 5 of Set 8 | san agustin
# Processing Record 6 of Set 8 | flinders
# Processing Record 7 of Set 8 | komsomolskiy
# Processing Record 8 of Set 8 | seydi
# Processing Record 9 of Set 8 | satka
# Processing Record 10 of Set 8 | mokhotlong
# Processing Record 11 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | paamiut
# Processing Record 15 of Set 8 | skotterud
# Processing Record 16 of Set 8 | mlonggo
# Processing Record 17 of Set 8 | menongue
# Processing Record 18 of Set 8 | pevek
# Processing Record 19 of Set 8 | san quintin
# Processing Record 20 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 8 | lasa
# Processing Record 22 of Set 8 | charleston
# Processing Record 23 of Set 8 | bairiki
# Processing Record 24 of Set 8 | najran
# Processing Record 25 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 8 | kragero
# Processing Record 27 of Set 8 | piney green
# Processing Record 28 of Set 8 | saumur
# Processing Record 29 of Set 8 | bulgan
# Processing Record 30 of Set 8 | manama
# Processing Record 31 of Set 8 | antofagasta
# Processing Record 32 of Set 8 | bontang
# Processing Record 33 of Set 8 | yerofey pavlovich
# Processing Record 34 of Set 8 | teahupoo
# Processing Record 35 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 8 | mwinilunga
# Processing Record 37 of Set 8 | ostersund
# Processing Record 38 of Set 8 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 39 of Set 8 | moron
# Processing Record 40 of Set 8 | haveli
# Processing Record 41 of Set 8 | chokurdakh
# Processing Record 42 of Set 8 | icod de los vinos
# Processing Record 43 of Set 8 | wanning
# Processing Record 44 of Set 8 | kaeo
# Processing Record 45 of Set 8 | loikaw
# Processing Record 46 of Set 8 | marystown
# Processing Record 47 of Set 8 | touros
# Processing Record 48 of Set 8 | arlit
# Processing Record 49 of Set 8 | sao pedro do sul
# Processing Record 50 of Set 8 | anadyr
# Processing Record 1 of Set 9 | boende
# Processing Record 2 of Set 9 | capreol
# Processing Record 3 of Set 9 | dargaville
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | cam ranh
# Processing Record 6 of Set 9 | orange
# Processing Record 7 of Set 9 | barra patuca
# Processing Record 8 of Set 9 | bogotol
# Processing Record 9 of Set 9 | vazhiny
# Processing Record 10 of Set 9 | tabou
# Processing Record 11 of Set 9 | zastron
# Processing Record 12 of Set 9 | heide
# Processing Record 13 of Set 9 | college
# Processing Record 14 of Set 9 | verkhoyansk
# Processing Record 15 of Set 9 | gladstone
# Processing Record 16 of Set 9 | sitka
# Processing Record 17 of Set 9 | tikrit
# Processing Record 18 of Set 9 | port augusta
# Processing Record 19 of Set 9 | olafsvik
# Processing Record 20 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | barberton
# Processing Record 23 of Set 9 | tautira
# Processing Record 24 of Set 9 | luderitz
# Processing Record 25 of Set 9 | haines junction
# Processing Record 26 of Set 9 | high level
# Processing Record 27 of Set 9 | maumere
# Processing Record 28 of Set 9 | medea
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | kichera
# Processing Record 31 of Set 9 | zhuhai
# Processing Record 32 of Set 9 | boyolangu
# Processing Record 33 of Set 9 | half moon bay
# Processing Record 34 of Set 9 | roebourne
# Processing Record 35 of Set 9 | besancon
# Processing Record 36 of Set 9 | romitan
# Processing Record 37 of Set 9 | te anau
# Processing Record 38 of Set 9 | tulagi
# Processing Record 39 of Set 9 | tabas
# Processing Record 40 of Set 9 | lalibela
# Processing Record 41 of Set 9 | waipawa
# Processing Record 42 of Set 9 | padang
# Processing Record 43 of Set 9 | aviles
# Processing Record 44 of Set 9 | aksu
# Processing Record 45 of Set 9 | bandarbeyla
# Processing Record 46 of Set 9 | tahe
# Processing Record 47 of Set 9 | makakilo city
# Processing Record 48 of Set 9 | port keats
# Processing Record 49 of Set 9 | aksarka
# Processing Record 50 of Set 9 | weiser
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 3 of Set 10 | plainview
# Processing Record 4 of Set 10 | honavar
# Processing Record 5 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 10 | kokopo
# Processing Record 7 of Set 10 | tsabong
# Processing Record 8 of Set 10 | faro
# Processing Record 9 of Set 10 | dwarka
# Processing Record 10 of Set 10 | northam
# Processing Record 11 of Set 10 | palmares do sul
# Processing Record 12 of Set 10 | hualmay
# Processing Record 13 of Set 10 | ginda
# Processing Record 14 of Set 10 | nelson
# Processing Record 15 of Set 10 | boda
# Processing Record 16 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 18 of Set 10 | baykit
# Processing Record 19 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 10 | kaitangata
# Processing Record 21 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | simav
# Processing Record 23 of Set 10 | qostanay
# Processing Record 24 of Set 10 | hambantota
# Processing Record 25 of Set 10 | okhotsk
# Processing Record 26 of Set 10 | taoudenni
# Processing Record 27 of Set 10 | dinard
# Processing Record 28 of Set 10 | darhan
# Processing Record 29 of Set 10 | montijo
# Processing Record 30 of Set 10 | papasquiaro
# City not found. Skipping...
# Processing Record 31 of Set 10 | ankazobe
# Processing Record 32 of Set 10 | puerres
# Processing Record 33 of Set 10 | aanekoski
# Processing Record 34 of Set 10 | venado tuerto
# Processing Record 35 of Set 10 | sterlibashevo
# Processing Record 36 of Set 10 | la huacana
# Processing Record 37 of Set 10 | ilo
# Processing Record 38 of Set 10 | duki
# Processing Record 39 of Set 10 | litovko
# Processing Record 40 of Set 10 | tessalit
# Processing Record 41 of Set 10 | bom jardim
# Processing Record 42 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 10 | provideniya
# Processing Record 44 of Set 10 | bisira
# Processing Record 45 of Set 10 | mount isa
# Processing Record 46 of Set 10 | gotsu
# Processing Record 47 of Set 10 | bumba
# Processing Record 48 of Set 10 | bloemfontein
# Processing Record 49 of Set 10 | at-bashi
# Processing Record 50 of Set 10 | hornepayne
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | along
# Processing Record 3 of Set 11 | acari
# Processing Record 4 of Set 11 | glendive
# Processing Record 5 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 11 | marawi
# Processing Record 7 of Set 11 | bavly
# Processing Record 8 of Set 11 | karratha
# Processing Record 9 of Set 11 | zavodouspenskoye
# Processing Record 10 of Set 11 | porto novo
# Processing Record 11 of Set 11 | vao
# Processing Record 12 of Set 11 | tombouctou
# Processing Record 13 of Set 11 | avera
# Processing Record 14 of Set 11 | raudeberg
# Processing Record 15 of Set 11 | isangel
# Processing Record 16 of Set 11 | altamira
# Processing Record 17 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 11 | teya
# Processing Record 19 of Set 11 | auki
# Processing Record 20 of Set 11 | mozarlandia
# Processing Record 21 of Set 11 | senden
# Processing Record 22 of Set 11 | mazyr
# Processing Record 23 of Set 11 | peniche
# Processing Record 24 of Set 11 | semnan
# Processing Record 25 of Set 11 | barsovo
# Processing Record 26 of Set 11 | pizarro
# Processing Record 27 of Set 11 | zaraza
# Processing Record 28 of Set 11 | belmonte
# Processing Record 29 of Set 11 | vila franca do campo
# Processing Record 30 of Set 11 | mawlaik
# Processing Record 31 of Set 11 | maua
# Processing Record 32 of Set 11 | batemans bay
# Processing Record 33 of Set 11 | aklavik
# Processing Record 34 of Set 11 | prado
# Processing Record 35 of Set 11 | bambanglipuro
# Processing Record 36 of Set 11 | kahului
# Processing Record 37 of Set 11 | yeppoon
# Processing Record 38 of Set 11 | naze
# Processing Record 39 of Set 11 | sobolevo
# Processing Record 40 of Set 11 | poya
# Processing Record 41 of Set 11 | ligayan
# Processing Record 42 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 11 | mashhad
# Processing Record 44 of Set 11 | malaya serdoba
# Processing Record 45 of Set 11 | cabo san lucas
# Processing Record 46 of Set 11 | kysyl-syr
# Processing Record 47 of Set 11 | salinopolis
# Processing Record 48 of Set 11 | koundara
# Processing Record 49 of Set 11 | ocna sugatag
# Processing Record 50 of Set 11 | garden city
# Processing Record 1 of Set 12 | krasnoselkup
# Processing Record 2 of Set 12 | cerrito
# Processing Record 3 of Set 12 | nara
# Processing Record 4 of Set 12 | bukachacha
# Processing Record 5 of Set 12 | timra
# Processing Record 6 of Set 12 | ixtapa
# Processing Record 7 of Set 12 | xuchang
# Processing Record 8 of Set 12 | inhambane
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | huarmey
# Processing Record 11 of Set 12 | tarakan
# Processing Record 12 of Set 12 | zamora
# Processing Record 13 of Set 12 | kirensk
# Processing Record 14 of Set 12 | kihei
# Processing Record 15 of Set 12 | calmar
# Processing Record 16 of Set 12 | deputatskiy
# Processing Record 17 of Set 12 | nyurba
# Processing Record 18 of Set 12 | sao joao da barra
# Processing Record 19 of Set 12 | smolenka
# Processing Record 20 of Set 12 | teguldet
# Processing Record 21 of Set 12 | lata
# Processing Record 22 of Set 12 | qasigiannguit
# Processing Record 23 of Set 12 | mahenge
# Processing Record 24 of Set 12 | katsuura
# Processing Record 25 of Set 12 | myitkyina
# Processing Record 26 of Set 12 | marzuq
# Processing Record 27 of Set 12 | yumen
# Processing Record 28 of Set 12 | acaponeta
# Processing Record 29 of Set 12 | conceicao do araguaia
# Processing Record 30 of Set 12 | shache
# Processing Record 31 of Set 12 | prince rupert
# Processing Record 32 of Set 12 | stillwater
# Processing Record 33 of Set 12 | luanda
# Processing Record 34 of Set 12 | cayenne
# Processing Record 35 of Set 12 | kokstad
# Processing Record 36 of Set 12 | ust-nera
# Processing Record 37 of Set 12 | homer
# Processing Record 38 of Set 12 | virginia beach
# Processing Record 39 of Set 12 | boksitogorsk
# Processing Record 40 of Set 12 | barvinkove
# Processing Record 41 of Set 12 | atambua
# Processing Record 42 of Set 12 | vzmorye
# Processing Record 43 of Set 12 | nanga eboko
# Processing Record 44 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 12 | amapa
# Processing Record 46 of Set 12 | jutai
# Processing Record 47 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 12 | gbarnga
# Processing Record 49 of Set 12 | a
# City not found. Skipping...
# Processing Record 50 of Set 12 | kumi
# Processing Record 1 of Set 13 | ngunguru
# Processing Record 2 of Set 13 | tours
# Processing Record 3 of Set 13 | christchurch
# Processing Record 4 of Set 13 | ketchikan
# Processing Record 5 of Set 13 | gardner
# Processing Record 6 of Set 13 | biskamzha
# Processing Record 7 of Set 13 | santa rosa
# Processing Record 8 of Set 13 | sturgis
# Processing Record 9 of Set 13 | kidal
# Processing Record 10 of Set 13 | porto velho
# Processing Record 11 of Set 13 | arvika
# Processing Record 12 of Set 13 | waddan
# Processing Record 13 of Set 13 | soyo
# Processing Record 14 of Set 13 | okha
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | cidreira
# Processing Record 17 of Set 13 | hammerfest
# Processing Record 18 of Set 13 | kavaratti
# Processing Record 19 of Set 13 | margate
# Processing Record 20 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 21 of Set 13 | kaabong
# Processing Record 22 of Set 13 | pokhara
# Processing Record 23 of Set 13 | kota belud
# Processing Record 24 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | chinna salem
# Processing Record 26 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 13 | xai-xai
# Processing Record 28 of Set 13 | lithakia
# Processing Record 29 of Set 13 | zabol
# Processing Record 30 of Set 13 | tornio
# Processing Record 31 of Set 13 | meadow lake
# Processing Record 32 of Set 13 | banda aceh
# Processing Record 33 of Set 13 | pangkalanbuun
# Processing Record 34 of Set 13 | maningrida
# Processing Record 35 of Set 13 | tandil
# Processing Record 36 of Set 13 | kilvelur
# Processing Record 37 of Set 13 | suluq
# Processing Record 38 of Set 13 | neuquen
# Processing Record 39 of Set 13 | saquarema
# Processing Record 40 of Set 13 | springbok
# Processing Record 41 of Set 13 | alice springs
# Processing Record 42 of Set 13 | nioro
# Processing Record 43 of Set 13 | kununurra
# Processing Record 44 of Set 13 | oron
# Processing Record 45 of Set 13 | zhangye
# Processing Record 46 of Set 13 | sorland
# Processing Record 47 of Set 13 | karasjok
# Processing Record 48 of Set 13 | chumikan
# Processing Record 49 of Set 13 | saint-louis
# Processing Record 50 of Set 13 | siverek
# Processing Record 1 of Set 14 | hinton
# Processing Record 2 of Set 14 | aberdeen
# Processing Record 3 of Set 14 | bom jesus
# Processing Record 4 of Set 14 | ornskoldsvik
# Processing Record 5 of Set 14 | san francisco
# Processing Record 6 of Set 14 | ust-tsilma
# Processing Record 7 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 14 | ust-ordynskiy
# Processing Record 10 of Set 14 | quetzaltepec
# City not found. Skipping...
# Processing Record 11 of Set 14 | nuuk
# Processing Record 12 of Set 14 | sanbu
# Processing Record 13 of Set 14 | erenhot
# Processing Record 14 of Set 14 | atasu
# Processing Record 15 of Set 14 | novozavidovskiy
# Processing Record 16 of Set 14 | dauphin
# Processing Record 17 of Set 14 | klyuchi
# Processing Record 18 of Set 14 | katangli
# Processing Record 19 of Set 14 | bolobo
# Processing Record 20 of Set 14 | kashi
# Processing Record 21 of Set 14 | byron bay
# Processing Record 22 of Set 14 | mims
# Processing Record 23 of Set 14 | hirado
# Processing Record 24 of Set 14 | piotrkow trybunalski
# Processing Record 25 of Set 14 | san juan
# Processing Record 26 of Set 14 | shulan
# Processing Record 27 of Set 14 | cabedelo
# Processing Record 28 of Set 14 | ulverstone
# Processing Record 29 of Set 14 | emerald
# Processing Record 30 of Set 14 | clonakilty
# Processing Record 31 of Set 14 | odweyne
# Processing Record 32 of Set 14 | san cristobal
# Processing Record 33 of Set 14 | jalu
# Processing Record 34 of Set 14 | flin flon
# Processing Record 35 of Set 14 | rio grande
# Processing Record 36 of Set 14 | puro
# Processing Record 37 of Set 14 | coquimbo
# Processing Record 38 of Set 14 | kongoussi
# Processing Record 39 of Set 14 | naron
# Processing Record 40 of Set 14 | nelson bay
# Processing Record 41 of Set 14 | lieksa
# Processing Record 42 of Set 14 | bundaberg
# Processing Record 43 of Set 14 | sandwick
# Processing Record 44 of Set 14 | dalvik
# Processing Record 45 of Set 14 | santa cruz
# Processing Record 46 of Set 14 | bakchar
# Processing Record 47 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 14 | kabanjahe
# Processing Record 50 of Set 14 | mayumba
# Processing Record 1 of Set 15 | salym
# Processing Record 2 of Set 15 | merauke
# Processing Record 3 of Set 15 | vanderhoof
# Processing Record 4 of Set 15 | lexington
# Processing Record 5 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 15 | kosh-agach
# Processing Record 7 of Set 15 | teberda
# Processing Record 8 of Set 15 | roma
# Processing Record 9 of Set 15 | kem
# Processing Record 10 of Set 15 | pingliang
# Processing Record 11 of Set 15 | fernley
# Processing Record 12 of Set 15 | cervo
# Processing Record 13 of Set 15 | tarrafal
# Processing Record 14 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 15 | safakulevo
# Processing Record 16 of Set 15 | nanning
# Processing Record 17 of Set 15 | kuytun
# Processing Record 18 of Set 15 | itoman
# Processing Record 19 of Set 15 | mosquera
# Processing Record 20 of Set 15 | tagusao
# Processing Record 21 of Set 15 | egvekinot
# Processing Record 22 of Set 15 | lamar
# Processing Record 23 of Set 15 | oranjemund
# Processing Record 24 of Set 15 | pacific grove
# Processing Record 25 of Set 15 | hibbing
# Processing Record 26 of Set 15 | novo aripuana
# Processing Record 27 of Set 15 | podor
# Processing Record 28 of Set 15 | talcahuano
# Processing Record 29 of Set 15 | sao paulo de olivenca
# Processing Record 30 of Set 15 | alness
# Processing Record 31 of Set 15 | jingdezhen
# Processing Record 32 of Set 15 | hazorasp
# Processing Record 33 of Set 15 | abha
# Processing Record 34 of Set 15 | cozumel
# Processing Record 35 of Set 15 | comodoro rivadavia
# Processing Record 36 of Set 15 | sovetskaya gavan
# Processing Record 37 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 38 of Set 15 | saint-prosper
# Processing Record 39 of Set 15 | bahia blanca
# Processing Record 40 of Set 15 | sambava
# Processing Record 41 of Set 15 | kumla
# Processing Record 42 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 15 | corn island
# Processing Record 44 of Set 15 | loralai
# Processing Record 45 of Set 15 | algiers
# Processing Record 46 of Set 15 | ambon
# Processing Record 47 of Set 15 | kamen-rybolov
# Processing Record 48 of Set 15 | sula
# Processing Record 49 of Set 15 | bowen
# Processing Record 50 of Set 15 | ipira
# Processing Record 1 of Set 16 | tateyama
# Processing Record 2 of Set 16 | berbera
# Processing Record 3 of Set 16 | north las vegas
# Processing Record 4 of Set 16 | jasper
# Processing Record 5 of Set 16 | nhulunbuy
# Processing Record 6 of Set 16 | xambioa
# Processing Record 7 of Set 16 | vaitape
# Processing Record 8 of Set 16 | camacha
# Processing Record 9 of Set 16 | morro da fumaca
# Processing Record 10 of Set 16 | bilma
# Processing Record 11 of Set 16 | grasse
# Processing Record 12 of Set 16 | tevriz
# Processing Record 13 of Set 16 | kavieng
# Processing Record 14 of Set 16 | bilibino
# Processing Record 15 of Set 16 | gweta
# Processing Record 16 of Set 16 | oktyabrskoye
# Processing Record 17 of Set 16 | razdolnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Broken Hill -31.9500  141.4333     58.26        37          13       16.78
# 1      Ushuaia -54.8000  -68.3000     44.26        57          40       18.41
# 2         Ilam  26.9167   87.9167     63.55        56           0        2.80
# 3    Jamestown  42.0970  -79.2353     54.99        94         100        8.05
# 4   Butaritari   3.0707  172.7902     81.03        69         100       15.84
# 5       Atuona  -9.8000 -139.0333     77.32        70           1       10.65
# 6        Vaini -21.2000 -175.2000     78.96        89          75       11.50
# 7         Tura  25.5198   90.2201     71.38        87          56        2.28
# 8    Ust-Ishim  57.6935   71.1665     35.47        90         100        8.05
# 9        Ancud -41.8697  -73.8203     49.60        84           0        0.94
#
#   Country                 Date
# 0      AU  2022-11-02 02:22:18
# 1      AR  2022-11-02 02:17:15
# 2      NP  2022-11-02 02:22:18
# 3      US  2022-11-02 02:12:49
# 4      KI  2022-11-02 02:17:17
# 5      PF  2022-11-02 02:17:32
# 6      TO  2022-11-02 02:17:38
# 7      IN  2022-11-02 02:22:19
# 8      RU  2022-11-02 02:22:19
# 9      CL  2022-11-02 02:19:14

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
#city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

column_names = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

city_data_df = city_data_df.reindex(columns = column_names)

# Recreate the DataFrame by using the new column order
city_data_df_reorder_df = pd.DataFrame(city_data_df)

# Display sample data
city_data_df_reorder_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Broken Hill      AU -31.9500  141.4333     58.26        37          13
# 1      Ushuaia      AR -54.8000  -68.3000     44.26        57          40
# 2         Ilam      NP  26.9167   87.9167     63.55        56           0
# 3    Jamestown      US  42.0970  -79.2353     54.99        94         100
# 4   Butaritari      KI   3.0707  172.7902     81.03        69         100
#
#    Wind Speed  Current Description
# 0       16.78                  NaN
# 1       18.41                  NaN
# 2        2.80                  NaN
# 3        8.05                  NaN
# 4       15.84                  NaN

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df_reorder_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label= 'City_ID')
