# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
#weather_api_key = ""
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | marawi
# Processing Record 3 of Set 1 | kirgiz-miyaki
# Processing Record 4 of Set 1 | pandan
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | lumeje
# Processing Record 7 of Set 1 | kenai
# Processing Record 8 of Set 1 | haines junction
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | shingu
# Processing Record 14 of Set 1 | russell
# Processing Record 15 of Set 1 | nuuk
# Processing Record 16 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | moyo
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | hami
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | camacha
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | bandarbeyla
# Processing Record 28 of Set 1 | bara
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | bullingen
# City not found. Skipping...
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | yar-sale
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | omsukchan
# Processing Record 41 of Set 1 | lorengau
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | chazuta
# Processing Record 44 of Set 1 | thunder bay
# Processing Record 45 of Set 1 | yandyki
# Processing Record 46 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | yumen
# Processing Record 49 of Set 1 | carutapera
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | hofn
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | filingue
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | payo
# Processing Record 7 of Set 2 | rawson
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | kemin
# Processing Record 10 of Set 2 | paamiut
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | vangaindrano
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | manado
# Processing Record 15 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 16 of Set 2 | kunashak
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | bereda
# Processing Record 19 of Set 2 | champasak
# Processing Record 20 of Set 2 | buraydah
# Processing Record 21 of Set 2 | san cristobal
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | charters towers
# Processing Record 26 of Set 2 | salamiyah
# Processing Record 27 of Set 2 | malanje
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | kamenka
# Processing Record 31 of Set 2 | ziguinchor
# Processing Record 32 of Set 2 | nabire
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 2 | tomas oppus
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | creston
# Processing Record 38 of Set 2 | new albany
# Processing Record 39 of Set 2 | sanming
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | zhuhai
# Processing Record 42 of Set 2 | teguldet
# Processing Record 43 of Set 2 | lima
# Processing Record 44 of Set 2 | banamba
# Processing Record 45 of Set 2 | salalah
# Processing Record 46 of Set 2 | portland
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 3 | poum
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | phangnga
# Processing Record 9 of Set 3 | iracoubo
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | egvekinot
# Processing Record 13 of Set 3 | waingapu
# Processing Record 14 of Set 3 | loreto
# Processing Record 15 of Set 3 | nelidovo
# Processing Record 16 of Set 3 | simoes
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | sydney
# Processing Record 22 of Set 3 | pochutla
# Processing Record 23 of Set 3 | boke
# Processing Record 24 of Set 3 | richards bay
# Processing Record 25 of Set 3 | agropoli
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | hobart
# Processing Record 28 of Set 3 | bassano
# Processing Record 29 of Set 3 | cintalapa
# Processing Record 30 of Set 3 | borogontsy
# Processing Record 31 of Set 3 | rudnya
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | ginda
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | berlevag
# Processing Record 38 of Set 3 | newport
# Processing Record 39 of Set 3 | camana
# Processing Record 40 of Set 3 | plouzane
# Processing Record 41 of Set 3 | road town
# Processing Record 42 of Set 3 | opuwo
# Processing Record 43 of Set 3 | xuddur
# Processing Record 44 of Set 3 | ayabaca
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | padang
# Processing Record 48 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | anadyr
# Processing Record 1 of Set 4 | qatana
# Processing Record 2 of Set 4 | sao geraldo do araguaia
# Processing Record 3 of Set 4 | emborion
# Processing Record 4 of Set 4 | yerbogachen
# Processing Record 5 of Set 4 | luanda
# Processing Record 6 of Set 4 | sistranda
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 4 | vianopolis
# Processing Record 10 of Set 4 | shalya
# Processing Record 11 of Set 4 | owando
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 14 of Set 4 | belozerskoye
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 4 | campo maior
# Processing Record 19 of Set 4 | nouadhibou
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | churapcha
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | skibbereen
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | miyazu
# Processing Record 28 of Set 4 | batemans bay
# Processing Record 29 of Set 4 | prince rupert
# Processing Record 30 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | marfino
# Processing Record 33 of Set 4 | quchan
# Processing Record 34 of Set 4 | yellowknife
# Processing Record 35 of Set 4 | tongchuan
# Processing Record 36 of Set 4 | omboue
# Processing Record 37 of Set 4 | lasa
# Processing Record 38 of Set 4 | natchitoches
# Processing Record 39 of Set 4 | namatanai
# Processing Record 40 of Set 4 | roald
# Processing Record 41 of Set 4 | kharp
# Processing Record 42 of Set 4 | mecca
# Processing Record 43 of Set 4 | kitimat
# Processing Record 44 of Set 4 | usinsk
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | lahan
# Processing Record 49 of Set 4 | kabare
# Processing Record 50 of Set 4 | sonepur
# Processing Record 1 of Set 5 | kropotkin
# Processing Record 2 of Set 5 | simao
# Processing Record 3 of Set 5 | pirovskoye
# Processing Record 4 of Set 5 | selfoss
# Processing Record 5 of Set 5 | maningrida
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | kitgum
# Processing Record 9 of Set 5 | boddam
# Processing Record 10 of Set 5 | bousso
# Processing Record 11 of Set 5 | along
# Processing Record 12 of Set 5 | kenitra
# Processing Record 13 of Set 5 | svetlaya
# Processing Record 14 of Set 5 | matara
# Processing Record 15 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 5 | atar
# Processing Record 17 of Set 5 | ahuimanu
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | phumi samraong
# City not found. Skipping...
# Processing Record 24 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | jackson
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | aguimes
# Processing Record 30 of Set 5 | buckingham
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | cabedelo
# Processing Record 33 of Set 5 | kaeo
# Processing Record 34 of Set 5 | carberry
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | nishihara
# Processing Record 37 of Set 5 | kutum
# Processing Record 38 of Set 5 | saint anthony
# Processing Record 39 of Set 5 | nantucket
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | jamestown
# Processing Record 42 of Set 5 | manggar
# Processing Record 43 of Set 5 | ariquemes
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | lohja
# Processing Record 46 of Set 5 | farmington
# Processing Record 47 of Set 5 | nicoya
# Processing Record 48 of Set 5 | solok
# Processing Record 49 of Set 5 | stanislav
# Processing Record 50 of Set 5 | inirida
# Processing Record 1 of Set 6 | rawicz
# Processing Record 2 of Set 6 | dali
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | kumla
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 8 of Set 6 | qostanay
# Processing Record 9 of Set 6 | lang son
# Processing Record 10 of Set 6 | kaihua
# Processing Record 11 of Set 6 | lake shore
# Processing Record 12 of Set 6 | talnakh
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | ukholovo
# Processing Record 15 of Set 6 | sao miguel do iguacu
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | natal
# Processing Record 18 of Set 6 | namie
# Processing Record 19 of Set 6 | san antonio
# Processing Record 20 of Set 6 | ostrovnoy
# Processing Record 21 of Set 6 | stoenesti
# Processing Record 22 of Set 6 | abnub
# Processing Record 23 of Set 6 | mbengwi
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | mao
# Processing Record 26 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 6 | liberal
# Processing Record 28 of Set 6 | semenivka
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | grudziadz
# Processing Record 31 of Set 6 | kontagora
# Processing Record 32 of Set 6 | monroe
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | pudozh
# Processing Record 35 of Set 6 | myitkyina
# Processing Record 36 of Set 6 | beasain
# Processing Record 37 of Set 6 | chuy
# Processing Record 38 of Set 6 | rokiskis
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | mahon
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | gurupa
# Processing Record 43 of Set 6 | linxia
# Processing Record 44 of Set 6 | tulun
# Processing Record 45 of Set 6 | mbaiki
# Processing Record 46 of Set 6 | jinchang
# Processing Record 47 of Set 6 | severo-kurilsk
# Processing Record 48 of Set 6 | goundam
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | katobu
# Processing Record 1 of Set 7 | masindi
# Processing Record 2 of Set 7 | ribera
# Processing Record 3 of Set 7 | huangnihe
# Processing Record 4 of Set 7 | poitiers
# Processing Record 5 of Set 7 | kembe
# Processing Record 6 of Set 7 | verkhoyansk
# Processing Record 7 of Set 7 | saveh
# Processing Record 8 of Set 7 | praia da vitoria
# Processing Record 9 of Set 7 | xinzhi
# Processing Record 10 of Set 7 | aosta
# Processing Record 11 of Set 7 | brattvag
# Processing Record 12 of Set 7 | jambi
# Processing Record 13 of Set 7 | ampanihy
# Processing Record 14 of Set 7 | pemberton
# Processing Record 15 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 7 | puerto leguizamo
# Processing Record 17 of Set 7 | hobyo
# Processing Record 18 of Set 7 | barreirinhas
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | kidal
# Processing Record 21 of Set 7 | abadan
# Processing Record 22 of Set 7 | norman wells
# Processing Record 23 of Set 7 | mantua
# Processing Record 24 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 7 | ongandjera
# Processing Record 26 of Set 7 | buala
# Processing Record 27 of Set 7 | picos
# Processing Record 28 of Set 7 | moussoro
# Processing Record 29 of Set 7 | armidale
# Processing Record 30 of Set 7 | palmer
# Processing Record 31 of Set 7 | nara
# Processing Record 32 of Set 7 | havoysund
# Processing Record 33 of Set 7 | tupik
# Processing Record 34 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 7 | plettenberg bay
# Processing Record 36 of Set 7 | port hardy
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | igarka
# Processing Record 39 of Set 7 | bubaque
# Processing Record 40 of Set 7 | alta floresta
# Processing Record 41 of Set 7 | borzya
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | shuyskoye
# Processing Record 44 of Set 7 | upernavik
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | sirjan
# Processing Record 47 of Set 7 | grindavik
# Processing Record 48 of Set 7 | bathsheba
# Processing Record 49 of Set 7 | kuandian
# Processing Record 50 of Set 7 | pimenteiras
# Processing Record 1 of Set 8 | grootfontein
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | el alto
# Processing Record 4 of Set 8 | teguise
# Processing Record 5 of Set 8 | longyearbyen
# Processing Record 6 of Set 8 | mount isa
# Processing Record 7 of Set 8 | praya
# Processing Record 8 of Set 8 | yaan
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | sabha
# Processing Record 11 of Set 8 | silivri
# Processing Record 12 of Set 8 | save
# Processing Record 13 of Set 8 | guozhen
# Processing Record 14 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 8 | geraldton
# Processing Record 16 of Set 8 | ukiah
# Processing Record 17 of Set 8 | de aar
# Processing Record 18 of Set 8 | palestine
# Processing Record 19 of Set 8 | provideniya
# Processing Record 20 of Set 8 | bridlington
# Processing Record 21 of Set 8 | bayir
# Processing Record 22 of Set 8 | ketchikan
# Processing Record 23 of Set 8 | biak
# Processing Record 24 of Set 8 | florida
# Processing Record 25 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | hithadhoo
# Processing Record 28 of Set 8 | paita
# Processing Record 29 of Set 8 | kaniama
# Processing Record 30 of Set 8 | kieta
# Processing Record 31 of Set 8 | hovd
# Processing Record 32 of Set 8 | santa cruz
# Processing Record 33 of Set 8 | grahamstown
# Processing Record 34 of Set 8 | manono
# Processing Record 35 of Set 8 | makarska
# Processing Record 36 of Set 8 | corner brook
# Processing Record 37 of Set 8 | hasaki
# Processing Record 38 of Set 8 | san vicente
# Processing Record 39 of Set 8 | los llanos de aridane
# Processing Record 40 of Set 8 | sindgi
# Processing Record 41 of Set 8 | rockhampton
# Processing Record 42 of Set 8 | miyako
# Processing Record 43 of Set 8 | nanakuli
# Processing Record 44 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 8 | dumbravita
# Processing Record 47 of Set 8 | namtsy
# Processing Record 48 of Set 8 | lubumbashi
# Processing Record 49 of Set 8 | songjianghe
# Processing Record 50 of Set 8 | phalombe
# Processing Record 1 of Set 9 | high level
# Processing Record 2 of Set 9 | lata
# Processing Record 3 of Set 9 | vardo
# Processing Record 4 of Set 9 | honghu
# Processing Record 5 of Set 9 | muisne
# Processing Record 6 of Set 9 | emerald
# Processing Record 7 of Set 9 | kommunisticheskiy
# Processing Record 8 of Set 9 | kavieng
# Processing Record 9 of Set 9 | beringovskiy
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 9 | arlit
# Processing Record 13 of Set 9 | concepcion
# Processing Record 14 of Set 9 | cockburn town
# Processing Record 15 of Set 9 | huarmey
# Processing Record 16 of Set 9 | tamandare
# Processing Record 17 of Set 9 | laranjeiras do sul
# Processing Record 18 of Set 9 | candido de abreu
# Processing Record 19 of Set 9 | gushikawa
# Processing Record 20 of Set 9 | doha
# Processing Record 21 of Set 9 | siavonga
# Processing Record 22 of Set 9 | kashiwazaki
# Processing Record 23 of Set 9 | pondicherry
# Processing Record 24 of Set 9 | penzance
# Processing Record 25 of Set 9 | koroni
# Processing Record 26 of Set 9 | rancho palos verdes
# Processing Record 27 of Set 9 | sharjah
# Processing Record 28 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 9 | luena
# Processing Record 30 of Set 9 | eydhafushi
# Processing Record 31 of Set 9 | melbu
# Processing Record 32 of Set 9 | saint george
# Processing Record 33 of Set 9 | aleksandrov gay
# Processing Record 34 of Set 9 | maine-soroa
# Processing Record 35 of Set 9 | lahaina
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | harindanga
# Processing Record 38 of Set 9 | cuauhtemoc
# Processing Record 39 of Set 9 | bardsir
# Processing Record 40 of Set 9 | sur
# Processing Record 41 of Set 9 | laguna
# Processing Record 42 of Set 9 | flinders
# Processing Record 43 of Set 9 | huilong
# Processing Record 44 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 9 | khandagayty
# Processing Record 46 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 9 | rajsamand
# Processing Record 48 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 9 | himare
# Processing Record 50 of Set 9 | henties bay
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | bowen
# Processing Record 3 of Set 10 | lavrentiya
# Processing Record 4 of Set 10 | waipawa
# Processing Record 5 of Set 10 | san pedro de macoris
# Processing Record 6 of Set 10 | bijie
# Processing Record 7 of Set 10 | bonito
# Processing Record 8 of Set 10 | sao joao da barra
# Processing Record 9 of Set 10 | kapoeta
# Processing Record 10 of Set 10 | lugovskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | helong
# Processing Record 12 of Set 10 | shimoda
# Processing Record 13 of Set 10 | byron bay
# Processing Record 14 of Set 10 | saint-augustin
# Processing Record 15 of Set 10 | marabba
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | senanga
# Processing Record 18 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 10 | boende
# Processing Record 20 of Set 10 | kyshtovka
# Processing Record 21 of Set 10 | oranjestad
# Processing Record 22 of Set 10 | abu kamal
# Processing Record 23 of Set 10 | sioux lookout
# Processing Record 24 of Set 10 | san rafael
# Processing Record 25 of Set 10 | santa rosa
# Processing Record 26 of Set 10 | antigonish
# Processing Record 27 of Set 10 | calabozo
# Processing Record 28 of Set 10 | inhambane
# Processing Record 29 of Set 10 | andros town
# Processing Record 30 of Set 10 | danielskuil
# Processing Record 31 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 10 | ati
# Processing Record 33 of Set 10 | port moresby
# Processing Record 34 of Set 10 | sola
# Processing Record 35 of Set 10 | batagay-alyta
# Processing Record 36 of Set 10 | kota
# Processing Record 37 of Set 10 | vao
# Processing Record 38 of Set 10 | chifeng
# Processing Record 39 of Set 10 | biograd na moru
# Processing Record 40 of Set 10 | trinidad
# Processing Record 41 of Set 10 | college
# Processing Record 42 of Set 10 | sal rei
# Processing Record 43 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 10 | koutiala
# Processing Record 45 of Set 10 | itarema
# Processing Record 46 of Set 10 | ambon
# Processing Record 47 of Set 10 | lukiv
# Processing Record 48 of Set 10 | adrar
# Processing Record 49 of Set 10 | kupino
# Processing Record 50 of Set 10 | makakilo city
# Processing Record 1 of Set 11 | houma
# Processing Record 2 of Set 11 | togur
# Processing Record 3 of Set 11 | goma
# Processing Record 4 of Set 11 | harper
# Processing Record 5 of Set 11 | tanete
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | kavaje
# Processing Record 8 of Set 11 | fortuna
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 11 of Set 11 | tondol
# Processing Record 12 of Set 11 | bulgan
# Processing Record 13 of Set 11 | mendoza
# Processing Record 14 of Set 11 | raudeberg
# Processing Record 15 of Set 11 | tual
# Processing Record 16 of Set 11 | bosaso
# Processing Record 17 of Set 11 | vlakhopoulon
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | sawakin
# Processing Record 20 of Set 11 | qasigiannguit
# Processing Record 21 of Set 11 | aranda de duero
# Processing Record 22 of Set 11 | sampang
# Processing Record 23 of Set 11 | marsa matruh
# Processing Record 24 of Set 11 | tiarei
# Processing Record 25 of Set 11 | forio
# Processing Record 26 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 11 | khor
# Processing Record 28 of Set 11 | constantine
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 11 | severnyy
# Processing Record 32 of Set 11 | asfi
# Processing Record 33 of Set 11 | valparaiso
# Processing Record 34 of Set 11 | nikki
# Processing Record 35 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 11 | walla walla
# Processing Record 37 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 11 | augusto correa
# Processing Record 39 of Set 11 | san rafael del sur
# Processing Record 40 of Set 11 | sobolevo
# Processing Record 41 of Set 11 | kota kinabalu
# Processing Record 42 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 43 of Set 11 | kikwit
# Processing Record 44 of Set 11 | buchmany
# Processing Record 45 of Set 11 | launceston
# Processing Record 46 of Set 11 | miraflores
# Processing Record 47 of Set 11 | ahipara
# Processing Record 48 of Set 11 | kahului
# Processing Record 49 of Set 11 | elko
# Processing Record 50 of Set 11 | nurota
# Processing Record 1 of Set 12 | feijo
# Processing Record 2 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 12 | luau
# Processing Record 4 of Set 12 | ternate
# Processing Record 5 of Set 12 | talara
# Processing Record 6 of Set 12 | kaseda
# Processing Record 7 of Set 12 | kashi
# Processing Record 8 of Set 12 | vestmannaeyjar
# Processing Record 9 of Set 12 | gogrial
# Processing Record 10 of Set 12 | panama city
# Processing Record 11 of Set 12 | aripuana
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | kardla
# Processing Record 14 of Set 12 | progreso
# Processing Record 15 of Set 12 | dasoguz
# Processing Record 16 of Set 12 | entre rios
# Processing Record 17 of Set 12 | ipojuca
# Processing Record 18 of Set 12 | sheregesh
# Processing Record 19 of Set 12 | dillon
# Processing Record 20 of Set 12 | rutul
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | shunyi
# Processing Record 23 of Set 12 | paracuru
# Processing Record 24 of Set 12 | asau
# Processing Record 25 of Set 12 | jamame
# Processing Record 26 of Set 12 | acarau
# Processing Record 27 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | uvira
# Processing Record 29 of Set 12 | soe
# Processing Record 30 of Set 12 | kharovsk
# Processing Record 31 of Set 12 | humaita
# Processing Record 32 of Set 12 | ouesso
# Processing Record 33 of Set 12 | dalvik
# Processing Record 34 of Set 12 | mitu
# Processing Record 35 of Set 12 | chara
# Processing Record 36 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 12 | tura
# Processing Record 38 of Set 12 | loukhi
# Processing Record 39 of Set 12 | kemijarvi
# Processing Record 40 of Set 12 | tatawin
# Processing Record 41 of Set 12 | muyezerskiy
# Processing Record 42 of Set 12 | pangai
# Processing Record 43 of Set 12 | kadoma
# Processing Record 44 of Set 12 | soyo
# Processing Record 45 of Set 12 | niquelandia
# Processing Record 46 of Set 12 | codo
# Processing Record 47 of Set 12 | koltubanovskiy
# Processing Record 48 of Set 12 | tuy hoa
# Processing Record 49 of Set 12 | boueni
# Processing Record 50 of Set 12 | kerema
# Processing Record 1 of Set 13 | canutama
# Processing Record 2 of Set 13 | chimore
# Processing Record 3 of Set 13 | kavaratti
# Processing Record 4 of Set 13 | novoagansk
# Processing Record 5 of Set 13 | luderitz
# Processing Record 6 of Set 13 | sotouboua
# Processing Record 7 of Set 13 | madaoua
# Processing Record 8 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 9 of Set 13 | gainesville
# Processing Record 10 of Set 13 | saint-pierre
# Processing Record 11 of Set 13 | pyaozerskiy
# Processing Record 12 of Set 13 | fairbanks
# Processing Record 13 of Set 13 | coquimbo
# Processing Record 14 of Set 13 | changji
# Processing Record 15 of Set 13 | youghal
# Processing Record 16 of Set 13 | valcourt
# Processing Record 17 of Set 13 | roma
# Processing Record 18 of Set 13 | port pirie
# Processing Record 19 of Set 13 | ouadda
# Processing Record 20 of Set 13 | labuhan
# Processing Record 21 of Set 13 | zhigalovo
# Processing Record 22 of Set 13 | ueckermunde
# Processing Record 23 of Set 13 | north platte
# Processing Record 24 of Set 13 | tlacojalpan
# Processing Record 25 of Set 13 | bardiyah
# Processing Record 26 of Set 13 | skjervoy
# Processing Record 27 of Set 13 | jumla
# Processing Record 28 of Set 13 | neuquen
# Processing Record 29 of Set 13 | dingle
# Processing Record 30 of Set 13 | seydi
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | baykit
# Processing Record 33 of Set 13 | kwinana
# Processing Record 34 of Set 13 | waddan
# Processing Record 35 of Set 13 | coihaique
# Processing Record 36 of Set 13 | mishan
# Processing Record 37 of Set 13 | yanam
# Processing Record 38 of Set 13 | brazzaville
# Processing Record 39 of Set 13 | boa vista
# Processing Record 40 of Set 13 | turukhansk
# Processing Record 41 of Set 13 | novyy buyan
# Processing Record 42 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 43 of Set 13 | kirakira
# Processing Record 44 of Set 13 | obo
# Processing Record 45 of Set 13 | leshukonskoye
# Processing Record 46 of Set 13 | torbay
# Processing Record 47 of Set 13 | opochka
# Processing Record 48 of Set 13 | angoche
# Processing Record 49 of Set 13 | maridi
# Processing Record 50 of Set 13 | honiara
# Processing Record 1 of Set 14 | utiel
# Processing Record 2 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 14 | lakatoro
# Processing Record 4 of Set 14 | dukat
# Processing Record 5 of Set 14 | eyl
# Processing Record 6 of Set 14 | okhotsk
# Processing Record 7 of Set 14 | madang
# Processing Record 8 of Set 14 | narsaq
# Processing Record 9 of Set 14 | rorvik
# Processing Record 10 of Set 14 | kulhudhuffushi
# Processing Record 11 of Set 14 | florence
# Processing Record 12 of Set 14 | zabaykalsk
# Processing Record 13 of Set 14 | san luis
# Processing Record 14 of Set 14 | salacgriva
# Processing Record 15 of Set 14 | vestmanna
# Processing Record 16 of Set 14 | pangnirtung
# Processing Record 17 of Set 14 | terra santa
# Processing Record 18 of Set 14 | mirnyy
# Processing Record 19 of Set 14 | nyurba
# Processing Record 20 of Set 14 | derzhavinsk
# Processing Record 21 of Set 14 | mandurah
# Processing Record 22 of Set 14 | cuiluan
# Processing Record 23 of Set 14 | lincoln
# Processing Record 24 of Set 14 | kushiro
# Processing Record 25 of Set 14 | vershino-shakhtaminskiy
# Processing Record 26 of Set 14 | juba
# Processing Record 27 of Set 14 | naze
# Processing Record 28 of Set 14 | griffith
# Processing Record 29 of Set 14 | saint stephen
# Processing Record 30 of Set 14 | kosh-agach
# Processing Record 31 of Set 14 | toktogul
# Processing Record 32 of Set 14 | enshi
# Processing Record 33 of Set 14 | gupitan
# Processing Record 34 of Set 14 | hihya
# Processing Record 35 of Set 14 | turangi
# Processing Record 36 of Set 14 | the pas
# Processing Record 37 of Set 14 | balykshi
# Processing Record 38 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 14 | riyadh
# Processing Record 40 of Set 14 | pilar
# Processing Record 41 of Set 14 | plymouth
# Processing Record 42 of Set 14 | kichera
# Processing Record 43 of Set 14 | alto araguaia
# Processing Record 44 of Set 14 | kota belud
# Processing Record 45 of Set 14 | mercedes
# Processing Record 46 of Set 14 | bonavista
# Processing Record 47 of Set 14 | safaga
# Processing Record 48 of Set 14 | great yarmouth
# Processing Record 49 of Set 14 | samarai
# Processing Record 50 of Set 14 | vilhena
# Processing Record 1 of Set 15 | victor harbor
# Processing Record 2 of Set 15 | kabo
# Processing Record 3 of Set 15 | pokhara
# Processing Record 4 of Set 15 | robe
# Processing Record 5 of Set 15 | pozo colorado
# Processing Record 6 of Set 15 | santiago del estero
# Processing Record 7 of Set 15 | san jeronimo
# Processing Record 8 of Set 15 | takhtamygda
# Processing Record 9 of Set 15 | impfondo
# Processing Record 10 of Set 15 | celestun
# Processing Record 11 of Set 15 | vila franca do campo
# Processing Record 12 of Set 15 | sekoma
# Processing Record 13 of Set 15 | karpathos
# Processing Record 14 of Set 15 | rokytne
# Processing Record 15 of Set 15 | athabasca
# Processing Record 16 of Set 15 | pozoblanco
# Processing Record 17 of Set 15 | andenes
# Processing Record 18 of Set 15 | iquique
# Processing Record 19 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 15 | hlukhiv
# Processing Record 21 of Set 15 | swan river
# Processing Record 22 of Set 15 | virginia beach
# Processing Record 23 of Set 15 | ust-nera
# Processing Record 24 of Set 15 | afgoye
# City not found. Skipping...
# Processing Record 25 of Set 15 | brownsville
# Processing Record 26 of Set 15 | zhangye
# Processing Record 27 of Set 15 | lazaro cardenas
# Processing Record 28 of Set 15 | hambantota
# Processing Record 29 of Set 15 | adamas
# Processing Record 30 of Set 15 | walvis bay
# Processing Record 31 of Set 15 | borovskoy
# Processing Record 32 of Set 15 | ginir
# Processing Record 33 of Set 15 | pahrump
# Processing Record 34 of Set 15 | wailuku
# Processing Record 35 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 15 | olinda
# Processing Record 37 of Set 15 | shubarshi
# Processing Record 38 of Set 15 | kysyl-syr
# Processing Record 39 of Set 15 | westport
# Processing Record 40 of Set 15 | domoni
# Processing Record 41 of Set 15 | quang ngai
# Processing Record 42 of Set 15 | urumqi
# Processing Record 43 of Set 15 | kodinsk
# Processing Record 44 of Set 15 | tautira
# Processing Record 45 of Set 15 | cedar city
# Processing Record 46 of Set 15 | sangin
# Processing Record 47 of Set 15 | imbituba
# Processing Record 48 of Set 15 | aborlan
# Processing Record 49 of Set 15 | la tuque
# Processing Record 50 of Set 15 | necochea
# Processing Record 1 of Set 16 | keti bandar
# Processing Record 2 of Set 16 | znamenskoye
# Processing Record 3 of Set 16 | garden city
# Processing Record 4 of Set 16 | ushi
# Processing Record 5 of Set 16 | quatre cocos
# Processing Record 6 of Set 16 | wiesbaden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Pevek  69.7008  170.3133      9.01        95         100
# 1           Marawi   7.9986  124.2928     69.80        90         100
# 2    Kirgiz-Miyaki  53.6324   54.7979     32.05        86          99
# 3           Pandan  14.0453  124.1694     80.26        86          86
# 4            Pisco -13.7000  -76.2167     66.02        77           0
# 5           Lumeje -11.5500   20.7833     68.77        84          84
# 6            Kenai  60.5544 -151.2583     32.14        80         100
# 7  Haines Junction  60.7522 -137.5108     12.15        92         100
# 8       Butaritari   3.0707  172.7902     81.97        70         100
# 9      Tuktoyaktuk  69.4541 -133.0374     14.00        79         100
#
#    Wind Speed Country                 Date
# 0        8.37      RU  2022-10-29 19:59:12
# 1        7.70      PH  2022-10-29 19:59:13
# 2        8.90      RU  2022-10-29 19:59:13
# 3       17.90      PH  2022-10-29 19:59:13
# 4       11.50      PE  2022-10-29 19:59:14
# 5        3.33      AO  2022-10-29 19:59:14
# 6       12.95      US  2022-10-29 19:59:15
# 7        1.14      CA  2022-10-29 19:59:15
# 8       14.63      KI  2022-10-29 19:59:16
# 9       13.80      CA  2022-10-29 19:59:16

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
#city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

column_names = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

city_data_df = city_data_df.reindex(columns = column_names)

# Recreate the DataFrame by using the new column order
city_data_df_reorder_df = pd.DataFrame(city_data_df)

# Display sample data
city_data_df_reorder_df.head()

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df_reorder.dtypes

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label= 'City_ID')

# %%
# Out:
#             City  Country  Lat  Lng  Max Temp Humidity  Cloudiness  \
# 0          Pevek     9.01   95  100      8.37       RU     69.7008
# 1         Marawi    69.80   90  100      7.70       PH      7.9986
# 2  Kirgiz-Miyaki    32.05   86   99      8.90       RU     53.6324
# 3         Pandan    80.26   86   86     17.90       PH     14.0453
# 4          Pisco    66.02   77    0     11.50       PE    -13.7000
#
#    Wind Speed  Current Description
# 0    170.3133  2022-10-29 19:59:12
# 1    124.2928  2022-10-29 19:59:13
# 2     54.7979  2022-10-29 19:59:13
# 3    124.1694  2022-10-29 19:59:13
# 4    -76.2167  2022-10-29 19:59:14
